# %% [markdown]
# <a href="https://colab.research.google.com/github/sr606/LinkedIn-Data-Mining-Analysis/blob/main/LinkedIn_Data_Mining_Analyzing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
connections = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Almabetter /EDA/LinkedIn/Connections1.csv')

# %%
connections.columns
# Out:
# Index(['First Name', 'Last Name', 'Full Name', 'Company', 'Position',
#        'Connected On'],
#       dtype='object')

# %%
connections.head()
# Out:
#   First Name Last Name       Full Name               Company  \
# 0   Shahrukh     Ahmad  Shahrukh Ahmad  Cartesian Consulting
# 1     Vishal    Jagtap   Vishal Jagtap     GlobalLogic India
# 2      Rahul     verma     Rahul verma            AlmaBetter
# 3     Shweta   Jamdade  Shweta Jamdade                   NaN
# 4     sakshi    sawant   sakshi sawant       pursuing B.tech
#
#                  Position Connected On
# 0            Data Analyst   19-08-2023
# 1  Software Test Engineer   19-08-2023
# 2    Data Science Trainee   19-08-2023
# 3                     NaN   19-08-2023
# 4                 Fresher   19-08-2023

# %%
connections.isna()
# Out:
#      First Name  Last Name  Full Name  Company  Position  Connected On
# 0         False      False      False    False     False         False
# 1         False      False      False    False     False         False
# 2         False      False      False    False     False         False
# 3         False      False      False     True      True         False
# 4         False      False      False    False     False         False
# ..          ...        ...        ...      ...       ...           ...
# 614       False      False      False    False     False         False
# 615       False      False      False    False     False         False
# 616       False      False      False    False     False         False
# 617       False      False      False     True      True         False
# 618       False      False      False     True      True         False
#
# [619 rows x 6 columns]

# %%
connections.isna().sum()
# Out:
# First Name        9
# Last Name         9
# Full Name         0
# Company         101
# Position        101
# Connected On      0
# dtype: int64

# %%
connections.shape
# Out:
# (619, 6)

# %%
connections.info
# Out:
# <bound method DataFrame.info of     First Name Last Name        Full Name                         Company  \
# 0     Shahrukh     Ahmad   Shahrukh Ahmad            Cartesian Consulting
# 1       Vishal    Jagtap    Vishal Jagtap               GlobalLogic India
# 2        Rahul     verma      Rahul verma                      AlmaBetter
# 3       Shweta   Jamdade   Shweta Jamdade                             NaN
# 4       sakshi    sawant    sakshi sawant                 pursuing B.tech
# ..         ...       ...              ...                             ...
# 614    Vaibhav   Bhosale  Vaibhav Bhosale  LTI - Larsen & Toubro Infotech
# 615     Rasika   Upadhye   Rasika Upadhye              Persistent Systems
# 616     Aditya     Yadav     Aditya Yadav                 Akruti solution
# 617      Rohan   Dingane    Rohan Dingane                             NaN
# 618   Satyajit    Chavan  Satyajit Chavan                             NaN
#
#                    Position Connected On
# 0              Data Analyst   19-08-2023
# 1    Software Test Engineer   19-08-2023
# 2      Data Science Trainee   19-08-2023
# 3                       NaN   19-08-2023
# 4                   Fresher   19-08-2023
# ..                      ...          ...
# 614       Senior Specialist    19-Mar-19
# 615  Lead Software Engineer    14-Mar-19
# 616                 Founder    12-Mar-19
# 617                     NaN    10-Mar-19
# 618                     NaN    08-Mar-19
#
# [619 rows x 6 columns]>

# %%
connections.dropna(inplace = True)

# %%
connections.shape
# Out:
# (518, 6)

# %%
connections.isna().sum()
# Out:
# First Name      0
# Last Name       0
# Full Name       0
# Company         0
# Position        0
# Connected On    0
# dtype: int64

# %%
invitations = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Almabetter /EDA/LinkedIn/Invitations.csv')

# %%
invitations.columns
# Out:
# Index(['From', 'To', 'Sent At', 'Message', 'Direction', 'inviterProfileUrn',
#        'inviteeProfileUrn'],
#       dtype='object')

# %%
invitations.shape
# Out:
# (224, 7)

# %%
invitations.head(20)
# Out:
#                From                   To           Sent At Message Direction  \
# 0   Shraddha Chavan          Prasad Wagh  8/15/23, 1:53 AM     NaN  OUTGOING
# 1   Shraddha Chavan  Shraddha Chandurkar  8/15/23, 1:44 AM     NaN  OUTGOING
# 2   Shraddha Chavan           Ajay Sable  8/15/23, 1:37 AM     NaN  OUTGOING
# 3   Shraddha Chavan       Dipanshu kumar  8/15/23, 1:28 AM     NaN  OUTGOING
# 4   Shraddha Chavan      Ashalata Barada  8/14/23, 7:19 AM     NaN  OUTGOING
# 5   Shraddha Chavan        Siddhi Thorat  8/14/23, 7:16 AM     NaN  OUTGOING
# 6   Shraddha Chavan        Vibhuti Gupta  8/14/23, 7:14 AM     NaN  OUTGOING
# 7   Shraddha Chavan              Shyam S  8/11/23, 9:30 PM     NaN  OUTGOING
# 8   Shraddha Chavan      Manisha Dhanuka   8/6/23, 1:21 AM     NaN  OUTGOING
# 9   Shraddha Chavan         Akshay Pawar   8/6/23, 1:20 AM     NaN  OUTGOING
# 10  Shraddha Chavan       Kaustubh Amare   8/6/23, 1:17 AM     NaN  OUTGOING
# 11  Shraddha Chavan      Charan Shivaram   8/6/23, 1:16 AM     NaN  OUTGOING
# 12  Shraddha Chavan          Rahul Gupta  7/29/23, 7:28 AM     NaN  OUTGOING
# 13  Shraddha Chavan              Nivya T  7/29/23, 7:22 AM     NaN  OUTGOING
# 14  Shraddha Chavan       Sanjay Jaiswal  7/29/23, 7:18 AM     NaN  OUTGOING
# 15  Shraddha Chavan         Sandipan Das  7/29/23, 7:16 AM     NaN  OUTGOING
# 16  Shraddha Chavan          Karan Rawat  7/29/23, 7:15 AM     NaN  OUTGOING
# 17  Shraddha Chavan               Bapu B  7/29/23, 7:14 AM     NaN  OUTGOING
# 18  Shraddha Chavan     Vishwajeet sutar  7/27/23, 5:08 AM     NaN  OUTGOING
# 19  Shraddha Chavan             Vivek CP  7/26/23, 4:46 AM     NaN  OUTGOING
#
#           inviterProfileUrn         inviteeProfileUrn
# 0   urn:li:member:666792457   urn:li:member:536059636
# 1   urn:li:member:666792457   urn:li:member:908658717
# 2   urn:li:member:666792457  urn:li:member:1016351361
# 3   urn:li:member:666792457   urn:li:member:784838207
# 4   urn:li:member:666792457  urn:li:member:1106288875
# 5   urn:li:member:666792457  urn:li:member:1157973962
# 6   urn:li:member:666792457   urn:li:member:974250037
# 7   urn:li:member:666792457   urn:li:member:206706591
# 8   urn:li:member:666792457   urn:li:member:606975107
# 9   urn:li:member:666792457  urn:li:member:1062537522
# 10  urn:li:member:666792457   urn:li:member:813000042
# 11  urn:li:member:666792457   urn:li:member:973378383
# 12  urn:li:member:666792457   urn:li:member:774433327
# 13  urn:li:member:666792457   urn:li:member:883691426
# 14  urn:li:member:666792457   urn:li:member:483090511
# 15  urn:li:member:666792457   urn:li:member:709039297
# 16  urn:li:member:666792457   urn:li:member:763389452
# 17  urn:li:member:666792457  urn:li:member:1007810615
# 18  urn:li:member:666792457   urn:li:member:944319169
# 19  urn:li:member:666792457   urn:li:member:664985573

# %%
invitations.isna().sum()
# Out:
# From                   0
# To                     0
# Sent At                0
# Message              221
# Direction              0
# inviterProfileUrn      0
# inviteeProfileUrn      0
# dtype: int64

# %%
invitations[invitations['Message'].notnull()].head()
# Out:
#                 From               To           Sent At  \
# 184  Ajith Pushparaj  Shraddha Chavan  5/11/23, 9:30 PM
# 196    Aiman Jamadar  Shraddha Chavan  5/4/23, 11:24 AM
# 206   Sam Andhorikar  Shraddha Chavan  4/22/23, 9:37 PM
#
#                                                Message Direction  \
# 184  Greetings Shraddha , I noticed we share an int...  INCOMING
# 196                                                 hi  INCOMING
# 206  Hey guys,  i'm looking for some good leaders w...  INCOMING
#
#            inviterProfileUrn        inviteeProfileUrn
# 184  urn:li:member:893018748  urn:li:member:666792457
# 196  urn:li:member:698675030  urn:li:member:666792457
# 206  urn:li:member:950983502  urn:li:member:666792457

# %%
invitations.shape
# Out:
# (224, 7)

# %%
invitations = invitations[invitations['Direction'] == 'INCOMING']

# %%
invitations.shape
# Out:
# (137, 7)

# %%
np.unique(invitations['Direction'])
# Out:
# array(['INCOMING'], dtype=object)

# %%
invitations['Company'] = ''
invitations.head()
# Out:
# <ipython-input-23-a53b075b8bb9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   invitations['Company'] = ''
#             From               To            Sent At Message Direction  \
# 87  Aditya Karve  Shraddha Chavan   8/20/23, 5:44 AM     NaN  INCOMING
# 88    Brinly Dot  Shraddha Chavan  8/18/23, 10:26 AM     NaN  INCOMING
# 89    Akash Bhor  Shraddha Chavan   8/18/23, 5:32 AM     NaN  INCOMING
# 90  Rutvik Patil  Shraddha Chavan   8/17/23, 8:36 AM     NaN  INCOMING
# 91   Suraj Kumar  Shraddha Chavan  8/17/23, 12:56 AM     NaN  INCOMING
#
#            inviterProfileUrn        inviteeProfileUrn Company
# 87   urn:li:member:996718690  urn:li:member:666792457
# 88  urn:li:member:1172525693  urn:li:member:666792457
# 89   urn:li:member:601433786  urn:li:member:666792457
# 90  urn:li:member:1034256430  urn:li:member:666792457
# 91   urn:li:member:869018630  urn:li:member:666792457

# %%
connections[connections['Full Name'] == 'Vishal Jagtap']['Company'].values[0]
# Out:
# 'GlobalLogic India'

# %%
len(invitations)
# Out:
# 137

# %%
invitations = invitations.reset_index(drop = True)
invitations
# Out:
#                    From               To            Sent At Message Direction  \
# 0          Aditya Karve  Shraddha Chavan   8/20/23, 5:44 AM     NaN  INCOMING
# 1            Brinly Dot  Shraddha Chavan  8/18/23, 10:26 AM     NaN  INCOMING
# 2            Akash Bhor  Shraddha Chavan   8/18/23, 5:32 AM     NaN  INCOMING
# 3          Rutvik Patil  Shraddha Chavan   8/17/23, 8:36 AM     NaN  INCOMING
# 4           Suraj Kumar  Shraddha Chavan  8/17/23, 12:56 AM     NaN  INCOMING
# ..                  ...              ...                ...     ...       ...
# 132       Arpit Rastogi  Shraddha Chavan  2/26/23, 10:32 PM     NaN  INCOMING
# 133      Girish P S Rao  Shraddha Chavan  2/26/23, 11:21 AM     NaN  INCOMING
# 134    Samruddhi Bakare  Shraddha Chavan   2/26/23, 2:28 AM     NaN  INCOMING
# 135  Vishwas Kshirsagar  Shraddha Chavan  2/26/23, 12:10 AM     NaN  INCOMING
# 136   Prashant Nalawade  Shraddha Chavan   2/23/23, 8:31 PM     NaN  INCOMING
#
#             inviterProfileUrn        inviteeProfileUrn Company
# 0     urn:li:member:996718690  urn:li:member:666792457
# 1    urn:li:member:1172525693  urn:li:member:666792457
# 2     urn:li:member:601433786  urn:li:member:666792457
# 3    urn:li:member:1034256430  urn:li:member:666792457
# 4     urn:li:member:869018630  urn:li:member:666792457
# ..                        ...                      ...     ...
# 132   urn:li:member:816295276  urn:li:member:666792457
# 133   urn:li:member:257416721  urn:li:member:666792457
# 134   urn:li:member:959959916  urn:li:member:666792457
# 135   urn:li:member:980270404  urn:li:member:666792457
# 136    urn:li:member:87751169  urn:li:member:666792457
#
# [137 rows x 8 columns]

# %%
for i in range(0, len(invitations)):
  #print(i, invitations['From'][i])
  try:
    company = connections[connections['Full Name'] == invitations['From'][i]]['Company'].values[0]
    #print(company)
    invitations['Company'][i] = company
  except:
    continue

# %%
invitations
# Out:
#                    From               To            Sent At Message Direction  \
# 0          Aditya Karve  Shraddha Chavan   8/20/23, 5:44 AM     NaN  INCOMING
# 1            Brinly Dot  Shraddha Chavan  8/18/23, 10:26 AM     NaN  INCOMING
# 2            Akash Bhor  Shraddha Chavan   8/18/23, 5:32 AM     NaN  INCOMING
# 3          Rutvik Patil  Shraddha Chavan   8/17/23, 8:36 AM     NaN  INCOMING
# 4           Suraj Kumar  Shraddha Chavan  8/17/23, 12:56 AM     NaN  INCOMING
# ..                  ...              ...                ...     ...       ...
# 132       Arpit Rastogi  Shraddha Chavan  2/26/23, 10:32 PM     NaN  INCOMING
# 133      Girish P S Rao  Shraddha Chavan  2/26/23, 11:21 AM     NaN  INCOMING
# 134    Samruddhi Bakare  Shraddha Chavan   2/26/23, 2:28 AM     NaN  INCOMING
# 135  Vishwas Kshirsagar  Shraddha Chavan  2/26/23, 12:10 AM     NaN  INCOMING
# 136   Prashant Nalawade  Shraddha Chavan   2/23/23, 8:31 PM     NaN  INCOMING
#
#             inviterProfileUrn        inviteeProfileUrn  \
# 0     urn:li:member:996718690  urn:li:member:666792457
# 1    urn:li:member:1172525693  urn:li:member:666792457
# 2     urn:li:member:601433786  urn:li:member:666792457
# 3    urn:li:member:1034256430  urn:li:member:666792457
# 4     urn:li:member:869018630  urn:li:member:666792457
# ..                        ...                      ...
# 132   urn:li:member:816295276  urn:li:member:666792457
# 133   urn:li:member:257416721  urn:li:member:666792457
# 134   urn:li:member:959959916  urn:li:member:666792457
# 135   urn:li:member:980270404  urn:li:member:666792457
# 136    urn:li:member:87751169  urn:li:member:666792457
#
#                                    Company
# 0
# 1                   Åbo Akademi University
# 2                     Clarion Technologies
# 3    Kalammawadi Wildlife Tourism pvt. Ltd
# 4                        Citizens Alliance
# ..                                     ...
# 132
# 133                      Ceplas Industrial
# 134
# 135                             topmate.io
# 136            Bajaj Electricals Ltd - T&D
#
# [137 rows x 8 columns]

# %%
invitations.drop(labels=['Message','Direction'], axis = 1, inplace = True)
invitations
# Out:
#                    From               To            Sent At  \
# 0          Aditya Karve  Shraddha Chavan   8/20/23, 5:44 AM
# 1            Brinly Dot  Shraddha Chavan  8/18/23, 10:26 AM
# 2            Akash Bhor  Shraddha Chavan   8/18/23, 5:32 AM
# 3          Rutvik Patil  Shraddha Chavan   8/17/23, 8:36 AM
# 4           Suraj Kumar  Shraddha Chavan  8/17/23, 12:56 AM
# ..                  ...              ...                ...
# 132       Arpit Rastogi  Shraddha Chavan  2/26/23, 10:32 PM
# 133      Girish P S Rao  Shraddha Chavan  2/26/23, 11:21 AM
# 134    Samruddhi Bakare  Shraddha Chavan   2/26/23, 2:28 AM
# 135  Vishwas Kshirsagar  Shraddha Chavan  2/26/23, 12:10 AM
# 136   Prashant Nalawade  Shraddha Chavan   2/23/23, 8:31 PM
#
#             inviterProfileUrn        inviteeProfileUrn  \
# 0     urn:li:member:996718690  urn:li:member:666792457
# 1    urn:li:member:1172525693  urn:li:member:666792457
# 2     urn:li:member:601433786  urn:li:member:666792457
# 3    urn:li:member:1034256430  urn:li:member:666792457
# 4     urn:li:member:869018630  urn:li:member:666792457
# ..                        ...                      ...
# 132   urn:li:member:816295276  urn:li:member:666792457
# 133   urn:li:member:257416721  urn:li:member:666792457
# 134   urn:li:member:959959916  urn:li:member:666792457
# 135   urn:li:member:980270404  urn:li:member:666792457
# 136    urn:li:member:87751169  urn:li:member:666792457
#
#                                    Company
# 0
# 1                   Åbo Akademi University
# 2                     Clarion Technologies
# 3    Kalammawadi Wildlife Tourism pvt. Ltd
# 4                        Citizens Alliance
# ..                                     ...
# 132
# 133                      Ceplas Industrial
# 134
# 135                             topmate.io
# 136            Bajaj Electricals Ltd - T&D
#
# [137 rows x 6 columns]

# %%
invitations.drop(labels=['From','To','Sent At'], axis = 1, inplace = True)
invitations
# Out:
#             inviterProfileUrn        inviteeProfileUrn  \
# 0     urn:li:member:996718690  urn:li:member:666792457
# 1    urn:li:member:1172525693  urn:li:member:666792457
# 2     urn:li:member:601433786  urn:li:member:666792457
# 3    urn:li:member:1034256430  urn:li:member:666792457
# 4     urn:li:member:869018630  urn:li:member:666792457
# ..                        ...                      ...
# 132   urn:li:member:816295276  urn:li:member:666792457
# 133   urn:li:member:257416721  urn:li:member:666792457
# 134   urn:li:member:959959916  urn:li:member:666792457
# 135   urn:li:member:980270404  urn:li:member:666792457
# 136    urn:li:member:87751169  urn:li:member:666792457
#
#                                    Company
# 0
# 1                   Åbo Akademi University
# 2                     Clarion Technologies
# 3    Kalammawadi Wildlife Tourism pvt. Ltd
# 4                        Citizens Alliance
# ..                                     ...
# 132
# 133                      Ceplas Industrial
# 134
# 135                             topmate.io
# 136            Bajaj Electricals Ltd - T&D
#
# [137 rows x 3 columns]

# %%
invitations.drop(labels=['inviterProfileUrn','inviteeProfileUrn'],axis = 1, inplace = True)
invitations
# Out:
#                                    Company
# 0
# 1                   Åbo Akademi University
# 2                     Clarion Technologies
# 3    Kalammawadi Wildlife Tourism pvt. Ltd
# 4                        Citizens Alliance
# ..                                     ...
# 132
# 133                      Ceplas Industrial
# 134
# 135                             topmate.io
# 136            Bajaj Electricals Ltd - T&D
#
# [137 rows x 1 columns]

# %%
invitations.to_csv('invitations.csv')

# %% [markdown]
# #**Generating Fake data**

# %%
connections.columns
# Out:
# Index(['First Name', 'Last Name', 'Full Name', 'Company', 'Position',
#        'Connected On'],
#       dtype='object')

# %%
connections.drop(labels = ['First Name','Last Name','Full Name'], axis = 1, inplace = True)
connections
# Out:
#                             Company                      Position Connected On
# 0              Cartesian Consulting                  Data Analyst   19-08-2023
# 1                 GlobalLogic India        Software Test Engineer   19-08-2023
# 2                        AlmaBetter          Data Science Trainee   19-08-2023
# 4                   pursuing B.tech                       Fresher   19-08-2023
# 5                 Citizens Alliance  Data Analytics and Scientist   19-08-2023
# ..                              ...                           ...          ...
# 612      Cooper Corporation Pvt Ltd                Engineer-R & D    06-Apr-19
# 613                   Digital Beats                 Founder & CEO    19-Mar-19
# 614  LTI - Larsen & Toubro Infotech             Senior Specialist    19-Mar-19
# 615              Persistent Systems        Lead Software Engineer    14-Mar-19
# 616                 Akruti solution                       Founder    12-Mar-19
#
# [518 rows x 3 columns]

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-19.3.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-19.3.1

# %%
from faker import Faker

# %%
fake = Faker()

# %%
fake.name()
# Out:
# 'James Martinez'

# %%
connections['Full Name'] = ''
connections
# Out:
#                             Company                      Position  \
# 0              Cartesian Consulting                  Data Analyst
# 1                 GlobalLogic India        Software Test Engineer
# 2                        AlmaBetter          Data Science Trainee
# 4                   pursuing B.tech                       Fresher
# 5                 Citizens Alliance  Data Analytics and Scientist
# ..                              ...                           ...
# 612      Cooper Corporation Pvt Ltd                Engineer-R & D
# 613                   Digital Beats                 Founder & CEO
# 614  LTI - Larsen & Toubro Infotech             Senior Specialist
# 615              Persistent Systems        Lead Software Engineer
# 616                 Akruti solution                       Founder
#
#     Connected On Full Name
# 0     19-08-2023
# 1     19-08-2023
# 2     19-08-2023
# 4     19-08-2023
# 5     19-08-2023
# ..           ...       ...
# 612    06-Apr-19
# 613    19-Mar-19
# 614    19-Mar-19
# 615    14-Mar-19
# 616    12-Mar-19
#
# [518 rows x 4 columns]

# %%
connections = connections.reset_index(drop = True)

# %%
for i in range(0, len(connections)):
  connections['Full Name'][i] = fake.name()

# %%
connections
# Out:
#                             Company                      Position  \
# 0              Cartesian Consulting                  Data Analyst
# 1                 GlobalLogic India        Software Test Engineer
# 2                        AlmaBetter          Data Science Trainee
# 3                   pursuing B.tech                       Fresher
# 4                 Citizens Alliance  Data Analytics and Scientist
# ..                              ...                           ...
# 513      Cooper Corporation Pvt Ltd                Engineer-R & D
# 514                   Digital Beats                 Founder & CEO
# 515  LTI - Larsen & Toubro Infotech             Senior Specialist
# 516              Persistent Systems        Lead Software Engineer
# 517                 Akruti solution                       Founder
#
#     Connected On          Full Name
# 0     19-08-2023      Jennifer Shah
# 1     19-08-2023   Mrs. Megan Baird
# 2     19-08-2023      Michelle Rose
# 3     19-08-2023     Jeff Rodriguez
# 4     19-08-2023    Michelle Palmer
# ..           ...                ...
# 513    06-Apr-19  Michael Armstrong
# 514    19-Mar-19        Julie Banks
# 515    19-Mar-19       Daniel Rojas
# 516    14-Mar-19      Richard Crane
# 517    12-Mar-19          Sean Pham
#
# [518 rows x 4 columns]

# %%
connections.to_csv('connections.csv')

# %% [markdown]
# #Messages

# %%
messages = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Almabetter /EDA/LinkedIn/messages.csv')

# %%
messages.columns
# Out:
# Index(['CONVERSATION ID', 'CONVERSATION TITLE', 'FROM', 'SENDER PROFILE URL',
#        'TO', 'RECIPIENT PROFILE URLS', 'DATE', 'SUBJECT', 'CONTENT', 'FOLDER'],
#       dtype='object')

# %%
messages.shape
# Out:
# (2346, 10)

# %%
messages.head(1)
# Out:
#                                      CONVERSATION ID CONVERSATION TITLE  \
# 0  2-ZDE0ZWJhODMtOGQ5MC00ZTgzLWJlMWMtNjUzNzQyNTk0...                NaN
#
#               FROM                                 SENDER PROFILE URL  \
# 0  Satyajit Chavan  https://www.linkedin.com/in/satyajit-chavan-20...
#
#                 TO                       RECIPIENT PROFILE URLS  \
# 0  Shraddha Chavan  https://www.linkedin.com/in/shraddhachavan9
#
#                       DATE SUBJECT CONTENT FOLDER
# 0  2023-08-23 15:18:59 UTC     NaN     NaN  INBOX

# %%
messages = messages['CONTENT']
messages
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#                               ...
# 2341    Hi %FIRSTNAME%,Based on your recent activity, ...
# 2342    Hi Shraddha,Based on your recent activity, I’d...
# 2343    Hi Shraddha,Based on your recent activity, I&r...
# 2344    I am Varadraj Nikam , a Financial Planner/ Adv...
# 2345    Hi,  I would like to personally invite you to ...
# Name: CONTENT, Length: 2346, dtype: object

# %%
messages.isna().sum()
# Out:
# 179

# %%
messages.dropna(inplace = True)
messages.shape
# Out:
# (2167,)

# %%
messages.to_csv('messages.csv')
